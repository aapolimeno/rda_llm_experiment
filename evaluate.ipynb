# %% [markdown]
# # Evaluation of LLM-generated metadata
# Models in question:
# - sonar-pro
# - llama-3.1-sonar-small-128k-online
# - mistral-small

# %%
import pandas as pd

# Load data
df = pd.read_csv("llm_output.csv", header=None)

# %%
# Add header
df.columns = ["lodAIC", "model", "prompt", "response", "dateTime", "stop reason"]

# %%
df[14:19]
# Out:
#                   lodAIC          model  \
# 14  pid_graph:APA44A99E4  mistral-small
# 15  pid_graph:AP47CC0B91  mistral-small
# 16  pid_graph:APD064DE2D  mistral-small
# 17  pid_graph:AP66BC0F2F  mistral-small
# 18  pid_graph:AP685862BE  mistral-small
#
#                                                prompt  \
# 14             **Instruction**:           You are ...
# 15            **Instruction**:           You are a...
# 16            **Instruction**:           You are a...
# 17             **Instruction**:           You are ...
# 18            **Instruction**:           You are a...
#
#                                              response             dateTime  \
# 14  Bitbucket: Community Governance, 0.9  Explanat...  2025-03-03 14:34:37
# 15  Book ID: Metadata Schema per Entity, 0.8  Expl...  2025-03-03 14:34:39
# 16                                    "no response "   2025-03-03 14:34:41
# 17  Book ID: Unknown, 0.6  I was unable to find sp...  2025-03-03 14:34:43
# 18  BusinessID: Unknown, 0.8  Explanation:  After ...  2025-03-03 14:34:45
#
#    stop reason
# 14        stop
# 15        stop
# 16        stop
# 17        stop
# 18        stop

# %%
df = df.replace("llama-3.1-sonar-small-128k-online", "llama-online")

# %%
df['prompt'] = df['prompt'].str.strip()  # removes leading/trailing whitespace

# %% [markdown]
# ### Add property variable

# %%
props = ["metadata", "structure", "governance"]

# %%
# Assign the property values to the new column
df['property'] = [props[i % len(props)] for i in range(len(df))]

# %%
df
# Out:
#                     lodAIC          model  \
# 0     pid_graph:AP0AEB083B  mistral-small
# 1     pid_graph:AP7D4E5ACB  mistral-small
# 2     pid_graph:APE39D4FF0  mistral-small
# 3     pid_graph:AP9364E21B  mistral-small
# 4     pid_graph:AP9DEF623A  mistral-small
# ...                    ...            ...
# 1183  pid_graph:AP8AC7F009   llama-online
# 1184  pid_graph:APCF11C735   llama-online
# 1185  pid_graph:APDB82E23B   llama-online
# 1186  pid_graph:AP4A7794ED   llama-online
# 1187  pid_graph:AP69D33426   llama-online
#
#                                                  prompt  \
# 0     **Instruction**:           You are an informat...
# 1     **Instruction**:           You are an informat...
# 2     **Instruction**:           You are an informat...
# 3     **Instruction**:           You are an informat...
# 4     **Instruction**:           You are an informat...
# ...                                                 ...
# 1183  **Instruction**:           You are an informat...
# 1184  **Instruction**:           You are an informat...
# 1185  **Instruction**:           You are an informat...
# 1186  **Instruction**:           You are an informat...
# 1187  **Instruction**:           You are an informat...
#
#                                                response             dateTime  \
# 0     AID: No Metadata Schema Prescribed, confidence...  2025-03-03 14:34:02
# 1     AID: Unknown, 0.5  Explanation:  The Persisten...  2025-03-03 14:34:04
# 2     AID: Unknown, 0.9  Explanation:  The Persisten...  2025-03-03 14:34:06
# 3     ARK: Metadata Schema per Entity, <confidence: ...  2025-03-03 14:34:11
# 4     ARK: Allows Managed Prefix, High Confidence  E...  2025-03-03 14:34:13
# ...                                                 ...                  ...
# 1183  **Z39.88-2004: No Prefix, 100%**  The identifi...  2025-03-04 13:39:08
# 1184  Z39.88-2004: **Community Governance**, **High*...  2025-03-04 13:39:11
# 1185  **zbMath: 2. Common Metadata Schema for Identi...  2025-03-04 13:39:14
# 1186  Given the Persistent Identifier (PID) structur...  2025-03-04 13:39:15
# 1187  zbMath: **Closed Governance**, **High Confiden...  2025-03-04 13:39:18
#
#      stop reason    property
# 0           stop    metadata
# 1           stop   structure
# 2           stop  governance
# 3           stop    metadata
# 4           stop   structure
# ...          ...         ...
# 1183        stop   structure
# 1184        stop  governance
# 1185        stop    metadata
# 1186        stop   structure
# 1187        stop  governance
#
# [1188 rows x 7 columns]

# %%
# Remove nan values
df = df.dropna()

# %%
df[14:19]
# Out:
#                   lodAIC          model  \
# 14  pid_graph:APA44A99E4  mistral-small
# 15  pid_graph:AP47CC0B91  mistral-small
# 16  pid_graph:APD064DE2D  mistral-small
# 17  pid_graph:AP66BC0F2F  mistral-small
# 18  pid_graph:AP685862BE  mistral-small
#
#                                                prompt  \
# 14  **Instruction**:           You are an informat...
# 15  **Instruction**:           You are an informat...
# 16  **Instruction**:           You are an informat...
# 17  **Instruction**:           You are an informat...
# 18  **Instruction**:           You are an informat...
#
#                                              response             dateTime  \
# 14  Bitbucket: Community Governance, 0.9  Explanat...  2025-03-03 14:34:37
# 15  Book ID: Metadata Schema per Entity, 0.8  Expl...  2025-03-03 14:34:39
# 16                                    "no response "   2025-03-03 14:34:41
# 17  Book ID: Unknown, 0.6  I was unable to find sp...  2025-03-03 14:34:43
# 18  BusinessID: Unknown, 0.8  Explanation:  After ...  2025-03-03 14:34:45
#
#    stop reason    property
# 14        stop  governance
# 15        stop    metadata
# 16        stop   structure
# 17        stop  governance
# 18        stop    metadata

# %% [markdown]
# ## Extract PIDs from prompt text

# %%
prompts = df.prompt.tolist()

# %%
for prompt in prompts: 
    if type(prompt) != str: 
        print(prompt)
        print(type(prompt))
        print("not a string")
        print("")

# %%
def get_pid(prompt): 
    front = prompt.split(" **Input**:")
    back = front[-1]
    target = back.split(" **Output**:")
    pid = target[0]
    return pid

# %%
# Extract all pids from the prompts
pids = [get_pid(prompt) for prompt in prompts]

# %%
# Add them to new dataframe column
df["pid"] = pids

# %%
df
# Out:
#                     lodAIC          model  \
# 0     pid_graph:AP0AEB083B  mistral-small
# 1     pid_graph:AP7D4E5ACB  mistral-small
# 2     pid_graph:APE39D4FF0  mistral-small
# 3     pid_graph:AP9364E21B  mistral-small
# 4     pid_graph:AP9DEF623A  mistral-small
# ...                    ...            ...
# 1183  pid_graph:AP8AC7F009   llama-online
# 1184  pid_graph:APCF11C735   llama-online
# 1185  pid_graph:APDB82E23B   llama-online
# 1186  pid_graph:AP4A7794ED   llama-online
# 1187  pid_graph:AP69D33426   llama-online
#
#                                                  prompt  \
# 0     **Instruction**:           You are an informat...
# 1     **Instruction**:           You are an informat...
# 2     **Instruction**:           You are an informat...
# 3     **Instruction**:           You are an informat...
# 4     **Instruction**:           You are an informat...
# ...                                                 ...
# 1183  **Instruction**:           You are an informat...
# 1184  **Instruction**:           You are an informat...
# 1185  **Instruction**:           You are an informat...
# 1186  **Instruction**:           You are an informat...
# 1187  **Instruction**:           You are an informat...
#
#                                                response             dateTime  \
# 0     AID: No Metadata Schema Prescribed, confidence...  2025-03-03 14:34:02
# 1     AID: Unknown, 0.5  Explanation:  The Persisten...  2025-03-03 14:34:04
# 2     AID: Unknown, 0.9  Explanation:  The Persisten...  2025-03-03 14:34:06
# 3     ARK: Metadata Schema per Entity, <confidence: ...  2025-03-03 14:34:11
# 4     ARK: Allows Managed Prefix, High Confidence  E...  2025-03-03 14:34:13
# ...                                                 ...                  ...
# 1183  **Z39.88-2004: No Prefix, 100%**  The identifi...  2025-03-04 13:39:08
# 1184  Z39.88-2004: **Community Governance**, **High*...  2025-03-04 13:39:11
# 1185  **zbMath: 2. Common Metadata Schema for Identi...  2025-03-04 13:39:14
# 1186  Given the Persistent Identifier (PID) structur...  2025-03-04 13:39:15
# 1187  zbMath: **Closed Governance**, **High Confiden...  2025-03-04 13:39:18
#
#      stop reason    property                   pid
# 0           stop    metadata         AID
# 1           stop   structure           AID
# 2           stop  governance           AID
# 3           stop    metadata         ARK
# 4           stop   structure           ARK
# ...          ...         ...                   ...
# 1183        stop   structure   Z39.88-2004
# 1184        stop  governance   Z39.88-2004
# 1185        stop    metadata      zbMath
# 1186        stop   structure        zbMath
# 1187        stop  governance        zbMath
#
# [1188 rows x 8 columns]

# %%
#df.to_csv("llm_output_clean.csv")

# %% [markdown]
# ## Extract all responses

# %%
# Extract all answers from the responses
def get_answer(row): 
    prop = row["property"]
    response = row["response"]

    if prop == "governance":
        options = ["Community Governance", "Membership Governance", "Closed Governance", "Unknown"] 
    
    elif prop == "metadata": 
        options = ["No Metadata Schema Prescribed", "Common Metadata Schema for Identifier", "Metadata Schema per Entity", "Custom/Non-Standard Metadata Schema", "Unknown" ]

    elif prop == "structure":
        options = ["Allows User Semantics", "Allows Managed Prefix", "No Prefix" , "Predefined Identifier Structure", "Unknown"]
    

    # Find the option that appears first in the response
    first_option = None
    first_index = len(response)  # Initialize with a value larger than any possible index

    for option in options: 
        index = response.find(option)
        if index != -1 and index < first_index:
            first_index = index
            first_option = option
            
    if first_option == None: 
        first_option = "Not found"

    return first_option

# %%
responses = df.response.tolist()
print(len(responses))
# Out:
# 1188

# %%
for prompt in responses: 
    if type(prompt) != str: 
        print(prompt)
        print(type(prompt))
        print("not a string")
        print("")

# %%
filtered_answers = df.apply(get_answer, axis=1)

# %%
c = 2
for ans in filtered_answers[:5]: 
    print(c, ans) 
    c += 1
# Out:
# 2 No Metadata Schema Prescribed
# 3 Unknown
# 4 Unknown
# 5 Metadata Schema per Entity
# 6 Allows Managed Prefix

# %%
df["short_response"] = filtered_answers

# %%
df
# Out:
#                     lodAIC          model  \
# 0     pid_graph:AP0AEB083B  mistral-small
# 1     pid_graph:AP7D4E5ACB  mistral-small
# 2     pid_graph:APE39D4FF0  mistral-small
# 3     pid_graph:AP9364E21B  mistral-small
# 4     pid_graph:AP9DEF623A  mistral-small
# ...                    ...            ...
# 1183  pid_graph:AP8AC7F009   llama-online
# 1184  pid_graph:APCF11C735   llama-online
# 1185  pid_graph:APDB82E23B   llama-online
# 1186  pid_graph:AP4A7794ED   llama-online
# 1187  pid_graph:AP69D33426   llama-online
#
#                                                  prompt  \
# 0     **Instruction**:           You are an informat...
# 1     **Instruction**:           You are an informat...
# 2     **Instruction**:           You are an informat...
# 3     **Instruction**:           You are an informat...
# 4     **Instruction**:           You are an informat...
# ...                                                 ...
# 1183  **Instruction**:           You are an informat...
# 1184  **Instruction**:           You are an informat...
# 1185  **Instruction**:           You are an informat...
# 1186  **Instruction**:           You are an informat...
# 1187  **Instruction**:           You are an informat...
#
#                                                response             dateTime  \
# 0     AID: No Metadata Schema Prescribed, confidence...  2025-03-03 14:34:02
# 1     AID: Unknown, 0.5  Explanation:  The Persisten...  2025-03-03 14:34:04
# 2     AID: Unknown, 0.9  Explanation:  The Persisten...  2025-03-03 14:34:06
# 3     ARK: Metadata Schema per Entity, <confidence: ...  2025-03-03 14:34:11
# 4     ARK: Allows Managed Prefix, High Confidence  E...  2025-03-03 14:34:13
# ...                                                 ...                  ...
# 1183  **Z39.88-2004: No Prefix, 100%**  The identifi...  2025-03-04 13:39:08
# 1184  Z39.88-2004: **Community Governance**, **High*...  2025-03-04 13:39:11
# 1185  **zbMath: 2. Common Metadata Schema for Identi...  2025-03-04 13:39:14
# 1186  Given the Persistent Identifier (PID) structur...  2025-03-04 13:39:15
# 1187  zbMath: **Closed Governance**, **High Confiden...  2025-03-04 13:39:18
#
#      stop reason    property                   pid  \
# 0           stop    metadata         AID
# 1           stop   structure           AID
# 2           stop  governance           AID
# 3           stop    metadata         ARK
# 4           stop   structure           ARK
# ...          ...         ...                   ...
# 1183        stop   structure   Z39.88-2004
# 1184        stop  governance   Z39.88-2004
# 1185        stop    metadata      zbMath
# 1186        stop   structure        zbMath
# 1187        stop  governance        zbMath
#
#                              short_response
# 0             No Metadata Schema Prescribed
# 1                                   Unknown
# 2                                   Unknown
# 3                Metadata Schema per Entity
# 4                     Allows Managed Prefix
# ...                                     ...
# 1183                              No Prefix
# 1184                   Community Governance
# 1185  Common Metadata Schema for Identifier
# 1186                              No Prefix
# 1187                      Closed Governance
#
# [1188 rows x 9 columns]

# %%
df = df.drop(columns=["prompt", "response", "dateTime", "stop reason"])
df.to_csv("llm_output_small.csv")

# %%
#df.to_csv("llm_output_rich.csv")

# %% [markdown]
# ### Pivot table

# %%
# Pivot the dataframe to have each model's response as a separate column
df_pivot = df.pivot(index=["property", "pid"], columns="model", values="short_response").reset_index()

# Rename columns for clarity (optional)
df_pivot.columns.name = None
df_pivot = df_pivot.rename(columns={
    'mistral-small': 'mistrall-small-response',
    'llama-online': 'llama-online-response',
    'sonar-pro': 'sonar-pro-response'
})

# %%
df_pivot
# Out:
#        property                 pid            llama-online-response  \
# 0    governance         AID                                  Unknown
# 1    governance         ARK                     Community Governance
# 2    governance     BibCode                     Community Governance
# 3    governance   Bitbucket                                  Unknown
# 4    governance     Book ID                     Community Governance
# ..          ...                 ...                              ...
# 391   structure        ePIC                    Allows Managed Prefix
# 392   structure     re3data          Predefined Identifier Structure
# 393   structure   rs number                    Allows User Semantics
# 394   structure      swMath          Predefined Identifier Structure
# 395   structure      zbMath                                No Prefix
#
#     mistrall-small-response               sonar-pro-response
# 0                   Unknown                          Unknown
# 1      Community Governance             Community Governance
# 2      Community Governance                Closed Governance
# 3      Community Governance                Closed Governance
# 4                   Unknown                          Unknown
# ..                      ...                              ...
# 391   Allows Managed Prefix            Allows Managed Prefix
# 392               Not found            Allows Managed Prefix
# 393   Allows Managed Prefix  Predefined Identifier Structure
# 394   Allows Managed Prefix                          Unknown
# 395   Allows Managed Prefix            Allows Managed Prefix
#
# [396 rows x 5 columns]

# %% [markdown]
# ### Agreement scores
# The agreement score can have a value between 1 and 3. Here's what they mean:
# - `3`: All three models give the same response
# - `2`: Two models give the same response
# - `1`: No models give the same response
#
# An additional value was added: `3: Unknown`. It means that all models agreed that the property information was unknown.

# %%
def get_agreement(row): 
    responses = [row.iloc[2], row.iloc[3], row.iloc[4]]
    unique_responses = set(responses)

    if len(unique_responses) == 1: 
        if "Unknown" in unique_responses: 
            return "3: Unknown"
        else:
            return 3
    if len(unique_responses) == 2: 
        return 2
    if len(unique_responses) == 3:  
        return 1

# %%
df_pivot["agreement"] = df_pivot.apply(get_agreement, axis=1)

# %%
df_pivot
# Out:
#        property                 pid            llama-online-response  \
# 0    governance         AID                                  Unknown
# 1    governance         ARK                     Community Governance
# 2    governance     BibCode                     Community Governance
# 3    governance   Bitbucket                                  Unknown
# 4    governance     Book ID                     Community Governance
# ..          ...                 ...                              ...
# 391   structure        ePIC                    Allows Managed Prefix
# 392   structure     re3data          Predefined Identifier Structure
# 393   structure   rs number                    Allows User Semantics
# 394   structure      swMath          Predefined Identifier Structure
# 395   structure      zbMath                                No Prefix
#
#     mistrall-small-response               sonar-pro-response   agreement
# 0                   Unknown                          Unknown  3: Unknown
# 1      Community Governance             Community Governance           3
# 2      Community Governance                Closed Governance           2
# 3      Community Governance                Closed Governance           1
# 4                   Unknown                          Unknown           2
# ..                      ...                              ...         ...
# 391   Allows Managed Prefix            Allows Managed Prefix           3
# 392               Not found            Allows Managed Prefix           1
# 393   Allows Managed Prefix  Predefined Identifier Structure           1
# 394   Allows Managed Prefix                          Unknown           1
# 395   Allows Managed Prefix            Allows Managed Prefix           2
#
# [396 rows x 6 columns]

# %%
#df_pivot.to_csv("llm_evaluation.csv")

# %% [markdown]
# #### Agreement count

# %%
# Agreement count of all properties
counts = df_pivot["agreement"].value_counts() 

counts
# Out:
# agreement
# 2             218
# 1             142
# 3              28
# 3: Unknown      8
# Name: count, dtype: int64

# %%
# Split the dataframe into three based on property, count the agreement values
df_governance = df_pivot[df_pivot["property"] == "governance"]
df_metadata = df_pivot[df_pivot["property"] == "metadata"]
df_structure = df_pivot[df_pivot["property"] == "structure"]

counts_governance = df_governance["agreement"].value_counts()
counts_metadata = df_metadata["agreement"].value_counts()
counts_structure = df_structure["agreement"].value_counts()

# %%
# Agreement count for governance property  

counts_governance
# Out:
# agreement
# 2             73
# 1             36
# 3             16
# 3: Unknown     7
# Name: count, dtype: int64

# %%
# Agreement count for metadata property

counts_metadata
# Out:
# agreement
# 2    77
# 1    50
# 3     5
# Name: count, dtype: int64

# %%
# Agreement count for structure property

counts_structure
# Out:
# agreement
# 2             68
# 1             56
# 3              7
# 3: Unknown     1
# Name: count, dtype: int64
